# %%
# Setup and image loading utilities
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image, display
import numpy as np

real_half_noise = 'results/half/accuracy/plots/average/Noise_Full_FL_avg.png'
real_full_noise = 'results/full/accuracy/plots/average/Noise_Full_FL_avg.png'

real_half_suppression = 'results/half/accuracy/plots/average/Suppression_Full_FL_avg.png'
real_full_suppression = 'results/full/accuracy/plots/average/Suppression_Full_FL_avg.png'

pred_p1_half_noise = 'results/half/accuracy/plots/average/Noise_Full_FL_P1_avg.png'
pred_p2_half_noise = 'results/half/accuracy/plots/average/Noise_Full_FL_P2_avg.png'
pred_p1_full_noise = 'results/full/accuracy/plots/average/Noise_Full_FL_P1_avg.png'
pred_p2_full_noise = 'results/full/accuracy/plots/average/Noise_Full_FL_P2_avg.png'

pred_p1_half_suppression = 'results/half/accuracy/plots/average/Suppression_Full_FL_P1_avg.png'
pred_p2_half_suppression = 'results/half/accuracy/plots/average/Suppression_Full_FL_P2_avg.png'
pred_p1_full_suppression = 'results/full/accuracy/plots/average/Suppression_Full_FL_P1_avg.png'
pred_p2_full_suppression = 'results/full/accuracy/plots/average/Suppression_Full_FL_P2_avg.png'

pred_average_half_noise = "results/half/accuracy/games/average/Noise_Final_Pred.png"
pred_average_full_noise = "results/full/accuracy/games/average/Noise_Final_Pred.png"

real_average_half_noise = "results/half/accuracy/games/average/Noise_Final_Real.png"
real_average_full_noise = "results/full/accuracy/games/average/Noise_Final_Real.png"

pred_average_half_suppression = "results/half/accuracy/games/average/Suppression_Final_Pred.png"
pred_average_full_suppression = "results/full/accuracy/games/average/Suppression_Final_Pred.png"

real_average_half_suppression = "results/half/accuracy/games/average/Suppression_Final_Real.png"
real_average_full_suppression = "results/full/accuracy/games/average/Suppression_Final_Real.png"

transformed_half_noise = "results/half/transformed/Noise_Transformed.png"
transformed_full_noise = "results/full/transformed/Noise_Transformed.png"

transformed_half_suppression = "results/half/transformed/Suppression_Transformed.png"
transformed_full_suppression = "results/full/transformed/Suppression_Transformed.png"

noise_params = np.load("results/full/transformed/Noise_Params.npy")
suppression_params = np.load("results/full/transformed/Suppression_Params.npy")

noise_scatter = "scatter_noise.png"
suppression_scatter = "scatter_suppression.png"

# %% [markdown]
# # Real Collaborative Results

# %% [markdown]
# ## Differentiol Privacy

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(real_half_noise))
axes[0].set_title('Half Partition Training')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_full_noise))
axes[1].set_title('Full Partition Training')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Suppression

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(real_half_suppression))
axes[0].set_title('Half Partition Training')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_full_suppression))
axes[1].set_title('Full Partition Training')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Predicted Results

# %% [markdown]
# ## Differential Privacy

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# --- Half Partition Figure (1 row, 2 columns) ---
fig_half, axes_half = plt.subplots(1, 2, figsize=(10, 5))
fig_half.suptitle('Half Partition', fontsize=16, fontweight='bold', y=0.98)

axes_half[0].imshow(mpimg.imread(pred_p1_half_noise))
axes_half[0].set_title('Participant 1')
axes_half[0].axis('off')

axes_half[1].imshow(mpimg.imread(pred_p2_half_noise))
axes_half[1].set_title('Participant 2')
axes_half[1].axis('off')

plt.tight_layout()
plt.show()

# --- Full Partition Figure (1 row, 2 columns) ---
fig_full, axes_full = plt.subplots(1, 2, figsize=(10, 5))
fig_full.suptitle('Full Partition', fontsize=16, fontweight='bold', y=0.98)

axes_full[0].imshow(mpimg.imread(pred_p1_full_noise))
axes_full[0].set_title('Participant 1')
axes_full[0].axis('off')

axes_full[1].imshow(mpimg.imread(pred_p2_full_noise))
axes_full[1].set_title('Participant 2')
axes_full[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Suppression

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# --- Half Partition Figure (1 row, 2 columns) ---
fig_half, axes_half = plt.subplots(1, 2, figsize=(10, 5))
fig_half.suptitle('Half Partition', fontsize=16, fontweight='bold', y=0.98)

axes_half[0].imshow(mpimg.imread(pred_p1_half_suppression))
axes_half[0].set_title('Participant 1')
axes_half[0].axis('off')

axes_half[1].imshow(mpimg.imread(pred_p2_half_suppression))
axes_half[1].set_title('Participant 2')
axes_half[1].axis('off')

plt.tight_layout()
plt.show()

# --- Full Partition Figure (1 row, 2 columns) ---
fig_full, axes_full = plt.subplots(1, 2, figsize=(10, 5))
fig_full.suptitle('Full Partition', fontsize=16, fontweight='bold', y=0.98)

axes_full[0].imshow(mpimg.imread(pred_p1_full_suppression))
axes_full[0].set_title('Participant 1')
axes_full[0].axis('off')

axes_full[1].imshow(mpimg.imread(pred_p2_full_suppression))
axes_full[1].set_title('Participant 2')
axes_full[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Averaged Results

# %% [markdown]
# ## Differential Privacy

# %% [markdown]
# ### Half dataset

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(pred_average_half_noise))
axes[0].set_title('Half Partition Real Average')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_average_half_noise))
axes[1].set_title('Half Partition Predicted Average')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Full dataset

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(pred_average_full_noise))
axes[0].set_title('Full Partition Real Average')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_average_full_noise))
axes[1].set_title('Full Partition Predicted Average')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Suppression

# %% [markdown]
# ### Half dataset

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(pred_average_half_suppression))
axes[0].set_title('Half Partition Predicted Average')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_average_half_suppression))
axes[1].set_title('Half Partition Real Average')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Full dataset

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(pred_average_full_suppression))
axes[0].set_title('Full Partition Predicted Average')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(real_average_full_suppression))
axes[1].set_title('Full Partition Real Average')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Monotonized Results

# %% [markdown]
# ## Differential Privacy

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(transformed_half_noise))
axes[0].set_title('Half Partition Monotonized')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(transformed_full_noise))
axes[1].set_title('Full Partition Monotonized')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Suppression

# %%
# Displaying Half and Full training heatmaps side by side with custom titles
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(mpimg.imread(transformed_half_suppression))
axes[0].set_title('Half Partition Monotonized')
axes[0].axis('off')

axes[1].imshow(mpimg.imread(transformed_full_suppression))
axes[1].set_title('Full Partition Monotonized')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Function params

# %% [markdown]
# ## Differential Privacy

# %% [markdown]
# ### Scatter Plot

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

axes.imshow(mpimg.imread(noise_scatter))
axes.set_title('Noise Scatter Plot')
axes.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Transformation Function Params

# %%
import numpy as np

# Tegyük fel, hogy a params tömböt betöltötted vagy megkaptad az optimalizálásból:
# pl. params = np.load("results/full/transformed/Noise_Params.npy")
# Vagy ha most futtatod: x, y, alpha, beta, gamma = params

x, y, alpha, beta, gamma = noise_params

# Formázott string (f-string) az egyenlet vizuális megjelenítésére
formula_string = (
    f"f(\\tilde{{\\Phi}}) = "
    f"({x:.4f} + {y:.4f} \\cdot D_n) \\cdot "
    f"({alpha:.4f} + {beta:.4f} \\cdot p_{{own}} + {gamma:.4f} \\cdot p_{{other}}) \\cdot \\tilde{{\\Phi}}"
)

# Jupyter Notebookban való szép, LaTeX alapú megjelenítéshez:
from IPython.display import DisplayObject, Markdown, display

display(
    Markdown(
        f"$$ {formula_string} $$"
    )
)
# Out:
# $$ f(\tilde{\Phi}) = (0.1350 + -0.0235 \cdot D_n) \cdot (7.6444 + 0.0442 \cdot p_{own} + 0.2318 \cdot p_{other}) \cdot \tilde{\Phi} $$

# %% [markdown]
# RMSE full  : 0.048212 -> 0.042830
#
# RMSE half  : 0.046009 -> 0.045157

# %% [markdown]
# ## Suppression

# %% [markdown]
# ### Scatter Plot

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

axes.imshow(mpimg.imread(suppression_scatter))
axes.set_title('Suppression Scatter Plot')
axes.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Transformation Function Params

# %%
import numpy as np

# Tegyük fel, hogy a params tömböt betöltötted vagy megkaptad az optimalizálásból:
# pl. params = np.load("results/full/transformed/Noise_Params.npy")
# Vagy ha most futtatod: x, y, alpha, beta, gamma = params

x, y, alpha, beta, gamma = suppression_params

# Formázott string (f-string) az egyenlet vizuális megjelenítésére
formula_string = (
    f"f(\\tilde{{\\Phi}}) = "
    f"({x:.4f} + {y:.4f} \\cdot D_n) \\cdot "
    f"({alpha:.4f} + {beta:.4f} \\cdot p_{{own}} + {gamma:.4f} \\cdot p_{{other}}) \\cdot \\tilde{{\\Phi}}"
)

# Jupyter Notebookban való szép, LaTeX alapú megjelenítéshez:
from IPython.display import Markdown, display

display(
    Markdown(
        f"$$ {formula_string} $$"
    )
)
# Out:
# $$ f(\tilde{\Phi}) = (-0.1813 + 0.0334 \cdot D_n) \cdot (-9.8627 + 0.3565 \cdot p_{own} + 0.4044 \cdot p_{other}) \cdot \tilde{\Phi} $$

# %% [markdown]
# RMSE full  : 1.586198 -> 0.466603
#
# RMSE half  : 1.646682 -> 0.382444
